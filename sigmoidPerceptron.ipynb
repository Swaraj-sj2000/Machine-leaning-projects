# %% [markdown]
# <a href="https://colab.research.google.com/github/Swaraj-sj2000/Machine-leaning-projects/blob/main/sigmoidPerceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

class SigmoidPerceptron:

  def __init__(self, input_size):
     self.weights = np.random.rand(input_size)
     self.bias = np.random.randn(1)

  def sigmoid(self, z):
      return 1 / (1 + np.exp(-z))

  def predict(self, inputs):
      weighted_sum = np.dot(inputs, self.weights) + self.bias
      return self.sigmoid(weighted_sum)

  def fit(self, inputs, targets, learning_rate, num_epochs):
      num_examples = inputs.shape[0]

      for epoch in range(num_epochs):
          for i in range(num_examples):
              input_vector = inputs[i]
              target = targets[i]

              prediction = self.predict(input_vector)
              error = target - prediction

              gradient_weights = error * prediction * (1 - prediction) * input_vector
              self.weights += learning_rate * gradient_weights

              gradient_bias = error * prediction * (1 - prediction)
              self.bias += learning_rate * gradient_bias

  def evaluate(self, inputs, targets):
      correct = 0
      for input_vector, target in zip(inputs, targets):
          prediction = self.predict(input_vector)

          if prediction >= 0.5:
              predicted_class = 1
          else:
              predicted_class = 0

          if predicted_class == target:
              correct += 1

      accuracy = correct / len(inputs)
      return accuracy

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('/content/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
df.shape
# Out:
# (768, 9)

# %%
class_0_df=df[df['Outcome']==0]
class_1_df=df[df['Outcome']==1]

# %%
class_0_df=class_0_df.sample(268)

# %%
data=pd.concat([class_0_df,class_1_df])

# %%
data.head()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 200            0      113             80             16        0  31.0
# 68             1       95             66             13       38  19.6
# 704            4      110             76             20      100  28.4
# 347            3      116              0              0        0  23.5
# 437            5      147             75              0        0  29.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 200                     0.874   21        0
# 68                      0.334   25        0
# 704                     0.118   27        0
# 347                     0.187   23        0
# 437                     0.434   28        0

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 755                     1.057   37        1
# 757                     0.258   52        1
# 759                     0.278   66        1
# 761                     0.403   43        1
# 766                     0.349   47        1

# %%
X=data.drop('Outcome',axis=1)
Y=data['Outcome']
X=X.values
Y=Y.values

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=42)

# %%
Scaler=StandardScaler()
X_train_scaled=Scaler.fit_transform(X_train)
X_test_scaled=Scaler.transform(X_test)

# %%
perceptron = SigmoidPerceptron(input_size=X_train_scaled.shape[1])

perceptron.fit(inputs=X_train_scaled,targets=Y_train,learning_rate=.1,num_epochs=100)
accuracy=perceptron.evaluate(X_train_scaled,Y_train)
print("train_accuracy=",accuracy)
# Out:
# train_accuracy= 0.7546728971962616

# %%
accuracy=perceptron.evaluate(X_test_scaled,Y_test)

# %%
print("test_accuracy=",accuracy)
# Out:
# test_accuracy= 0.8148148148148148
